# %%
import re
import datetime
import requests
import pandas as pd
from bs4 import BeautifulSoup
from datetime import timedelta,date

# %%
results = requests.get('https://nation.africa/kenya/news/tech')
results.url
# Out:
# 'https://nation.africa/kenya/news/tech'

# %%
results
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(results.content, 'lxml')
soup
# Out:
# <!DOCTYPE html>
# <!--[if IE 9]><html lang="en" class="ie9"><![endif]--><html dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="Nation" property="og:site_name"/>
# <title>Tech | Nation</title>
# <meta content="Tech" property="og:title"/>
# <meta content="Latest news, updates, releases and reviews of latest technology, gadgets, mobiles, hardware, software, social media on Nation.Africa" name="description"/>
# <meta content="Latest news, updates, releases and reviews of latest technology, gadgets, mobiles, hardware, software, social media on Nation.Africa" property="og:description"/>
# <meta content="https://nation.africa/kenya/news/tech" property="og:url"/>
# <meta content="en" property="og:locale"/>
# <meta content="en_US" property="og:locale:alternate"/>
# ...

# %%
base_url = "https://nation.africa"
containers = soup.findAll('section', {'class': 'medium-col-2-3'})
for container in containers:
    title =  container.a['aria-label']
    title1 = container.h3.text
    post_url = base_url + container.a['href']
    teaser = container.p.text
    category = container.find('span', {'article-topic'}).text
    posttime = container.find('span', {'date'}).text
    print(title, post_url)
    print(teaser,category, posttime)
# Out:
# Facebook pulls pages linked to ex-Trump aide Steve Bannon https://nation.africa/kenya/business/technology/facebook-pulls-pages-linked-to-ex-trump-aide-steve-bannon-3017450
#
# The social media giant took down seven pages directly linked to Bannon. Technology
# Nov 10

# %%
section2 = soup.findAll('ol', {'class': 'article-collection'})
for container in section2:
    for list_item in container.findAll('li'):
        post_url = base_url + list_item.a['href']
        title =  list_item.a['aria-label']
        category = list_item.find('span', {'article-topic'}).text
        posttime = list_item.find('span', {'date'}).text
        print(category, posttime)
# Out:
# Technology
# Nov 03
#
# Technology
# Oct 30
#
# Technology
# Oct 29
#
# Nakuru
# Oct 27
